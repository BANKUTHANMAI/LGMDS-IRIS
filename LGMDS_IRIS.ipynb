# %% [markdown]
# <a href="https://colab.research.google.com/github/BANKUTHANMAI/LGMDS-IRIS/blob/main/LGMDS_IRIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataframe=pd.read_csv("/content/irisdata.txt",names=columns)

# %%
dataframe.head
# Out:
# <bound method NDFrame.head of      Sepal length  Sepal width  Petal length  Petal width           Class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %%
dataframe.tail
# Out:
# <bound method NDFrame.tail of      Sepal length  Sepal width  Petal length  Petal width           Class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %%
dataframe.shape
# Out:
# (150, 5)

# %%
dataframe.describe()
# Out:
#        Sepal length  Sepal width  Petal length  Petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
duplicate = dataframe[dataframe.duplicated()]
print(duplicate)
# Out:
#      Sepal length  Sepal width  Petal length  Petal width           Class
# 34            4.9          3.1           1.5          0.1     Iris-setosa
# 37            4.9          3.1           1.5          0.1     Iris-setosa
# 142           5.8          2.7           5.1          1.9  Iris-virginica

# %%
(dataframe.isna().sum())
# Out:
# Sepal length    0
# Sepal width     0
# Petal length    0
# Petal width     0
# Class           0
# dtype: int64

# %%
dataframe.hist()
plt.show()

# %%
columns = ['Sepal length', 'Sepal width', 'Petal length', 'Petal width', 'Class']

# %%
sns.violinplot(y='Class', x='Sepal length', data=dataframe, inner='quartile')
plt.show()
sns.violinplot(y='Class', x='Sepal width', data=dataframe, inner='quartile')
plt.show()
sns.violinplot(y='Class', x='Petal length', data=dataframe, inner='quartile')
plt.show()
sns.violinplot(y='Class', x='Petal width', data=dataframe, inner='quartile')
plt.show()

# %%
sns.pairplot(dataframe, hue='Class', markers='+')
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.heatmap(dataframe.corr(), annot=True, cmap='cubehelix_r')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x = dataframe.iloc[:,:-1].values
y = dataframe.iloc[:,-1].values
x_train,x_test, y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier,AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
rfc = RandomForestClassifier(n_estimators=50,max_depth=20,random_state=2)
rfc.fit(x_train,y_train)
y_pred_rfc = rfc.predict(x_test)
ac_rfc=accuracy_score(y_test,y_pred_rfc)
print(ac_rfc)
cr_rfc=classification_report(y_test,y_pred_rfc)
print(cr_rfc)
# Out:
# 0.9666666666666667
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      0.92      0.96        13
#  Iris-virginica       0.86      1.00      0.92         6
#
#        accuracy                           0.97        30
#       macro avg       0.95      0.97      0.96        30
#    weighted avg       0.97      0.97      0.97        30

# %%
dtc = DecisionTreeClassifier(max_depth=30,random_state=1)
dtc.fit(x_train,y_train)
y_pred_dtc = dtc.predict(x_test)
ac_dtc=accuracy_score(y_test,y_pred_dtc)
print(ac_dtc)
cr_dtc=classification_report(y_test,y_pred_dtc)
print(cr_dtc)
# Out:
# 0.9666666666666667
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      0.92      0.96        13
#  Iris-virginica       0.86      1.00      0.92         6
#
#        accuracy                           0.97        30
#       macro avg       0.95      0.97      0.96        30
#    weighted avg       0.97      0.97      0.97        30

# %%
gbc = GradientBoostingClassifier(n_estimators=50,learning_rate=0.3)
gbc.fit(x_train,y_train)
y_pred_gbc = gbc.predict(x_test)
ac_gbc=accuracy_score(y_test,y_pred_gbc)
print(ac_gbc)
cr_gbc=classification_report(y_test,y_pred_gbc)
print(cr_gbc)
# Out:
# 0.9666666666666667
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      0.92      0.96        13
#  Iris-virginica       0.86      1.00      0.92         6
#
#        accuracy                           0.97        30
#       macro avg       0.95      0.97      0.96        30
#    weighted avg       0.97      0.97      0.97        30

# %%
gnb = GaussianNB(var_smoothing=0.0001)
gnb.fit(x_train,y_train)
y_pred_gnb = gnb.predict(x_test)
ac_gnb=accuracy_score(y_test,y_pred_gnb)
print(ac_gnb)
cr_gnb=classification_report(y_test,y_pred_gnb)
print(cr_gnb)
# Out:
# 0.9666666666666667
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      0.92      0.96        13
#  Iris-virginica       0.86      1.00      0.92         6
#
#        accuracy                           0.97        30
#       macro avg       0.95      0.97      0.96        30
#    weighted avg       0.97      0.97      0.97        30

# %%
clf=AdaBoostClassifier(random_state=96,base_estimator=RandomForestClassifier(random_state=12),n_estimators=10,learning_rate=0.01)
clf.fit(x_train,y_train)
y_pred_clf = clf.predict(x_test)
ac_clf=accuracy_score(y_test,y_pred_clf)
print(ac_clf)
cr_clf=classification_report(y_test,y_pred_clf)
print(cr_clf)
# Out:
# 0.9666666666666667
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      0.92      0.96        13
#  Iris-virginica       0.86      1.00      0.92         6
#
#        accuracy                           0.97        30
#       macro avg       0.95      0.97      0.96        30
#    weighted avg       0.97      0.97      0.97        30

# %%
knn=KNeighborsClassifier(n_neighbors=15)
knn.fit(x_train,y_train)
y_pred_knn = knn.predict(x_test)
ac_knn=accuracy_score(y_test,y_pred_knn)
print(ac_knn)
cr_knn=classification_report(y_test,y_pred_knn)
print(cr_knn)
# Out:
# 0.9666666666666667
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      0.92      0.96        13
#  Iris-virginica       0.86      1.00      0.92         6
#
#        accuracy                           0.97        30
#       macro avg       0.95      0.97      0.96        30
#    weighted avg       0.97      0.97      0.97        30

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
prediction = model.predict(x_test)
print('Accuracy:',accuracy_score(prediction,y_test))
# Out:
# Accuracy: 0.9666666666666667

# %%
from sklearn.tree import DecisionTreeClassifier
modeldt = DecisionTreeClassifier(criterion='entropy',random_state=5)
modeldt.fit(x_train,y_train)
y_pred = modeldt.predict(x_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score: 0.9666666666666667

# %%
from sklearn.metrics import confusion_matrix
cm_rfc = confusion_matrix(y_test,y_pred_rfc)
cm_dtc = confusion_matrix(y_test,y_pred_dtc)
cm_gbc = confusion_matrix(y_test,y_pred_gbc)
cm_gnb = confusion_matrix(y_test,y_pred_gnb)
cm_clf = confusion_matrix(y_test,y_pred_clf)
cm_knn = confusion_matrix(y_test,y_pred_knn)
print(cm_rfc)
print(cm_dtc)
print(cm_gbc)
print(cm_gnb)
print(cm_clf)
print(cm_knn)
# Out:
# [[11  0  0]
#  [ 0 12  1]
#  [ 0  0  6]]
# [[11  0  0]
#  [ 0 12  1]
#  [ 0  0  6]]
# [[11  0  0]
#  [ 0 12  1]
#  [ 0  0  6]]
# [[11  0  0]
#  [ 0 12  1]
#  [ 0  0  6]]
# [[11  0  0]
#  [ 0 12  1]
#  [ 0  0  6]]
# [[11  0  0]
#  [ 0 12  1]
#  [ 0  0  6]]

# %%
print('Random Forest:',ac_rfc)
print('Decision Tree Classifier:',ac_dtc)
print('Gradient Boosting:',ac_gbc)
print('Guassian NB:',ac_gnb)
print('AdaBoost Classifier:',ac_clf)
print('KNN:',ac_knn)
# Out:
# Random Forest: 0.9666666666666667
# Decision Tree Classifier: 0.9666666666666667
# Gradient Boosting: 0.9666666666666667
# Guassian NB: 0.9666666666666667
# AdaBoost Classifier: 0.9666666666666667
# KNN: 0.9666666666666667
